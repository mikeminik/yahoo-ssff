# %%
import os
import sys
from logging import DEBUG
from pathlib import Path

from dotenv import load_dotenv

from yfpy import Data
from yfpy.logger import get_logger
from yfpy.query import YahooFantasySportsQuery

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import json
# Out:
# [2023-12-18 17:21:37,030 DEBUG] [matplotlib.__init__.wrapper] CACHEDIR=C:\Users\mikem\.matplotlib
# [2023-12-18 17:21:37,037 DEBUG] [matplotlib.font_manager.font_manager._load_fontmanager] Using fontManager instance from C:\Users\mikem\.matplotlib\fontlist-v330.json
# [2023-12-18 17:21:37,037 DEBUG] [matplotlib.font_manager.font_manager._load_fontmanager] Using fontManager instance from C:\Users\mikem\.matplotlib\fontlist-v330.json

# %% [markdown]
# ### Environment variables

# %%
project_dir = os.path.abspath('')

# %%
sys.path.insert(0, str(project_dir))

# %%
load_dotenv(dotenv_path=f"{project_dir}/auth/.env")
# Out:
# True

# %% [markdown]
# ### Set directories

# %%
auth_dir = f"{project_dir}/auth"

# %%
data_dir = f"{project_dir}/output"

# %% [markdown]
# ### Regenerate functions

# %%
def write_league_standings(game_keys, league_ids):
    for year, id in zip(game_keys['season'], game_keys['code']):
        print(f"Attempting to write year {year}")
        yahoo_query = YahooFantasySportsQuery(
                auth_dir,
                league_id=league_ids[str(year)],
                game_code='nfl',
                game_id=id
            )
        try:
            data.save(file_name=f"standings_year_{year}", yf_query=yahoo_query.get_league_standings)
        except:
            print(f"Could not save data for year: {year}, code: {id}")
        else:
            pass

# %% [markdown]
# ### Load data

# %%
data = Data(data_dir)

# %%
game_keys = data.load("game keys")

# %%
game_keys_list = []
for game in game_keys:
    entry = {'season': game.season, 'code': game.game_id}
    game_keys_list.append(entry)

# %%
game_keys_df = pd.DataFrame(game_keys_list)

# %%
game_keys_df = game_keys_df[game_keys_df['season'] > 2014]

# %%
game_keys_df
# Out:
#     season  code
# 16    2015   348
# 17    2016   359
# 18    2017   371
# 19    2018   380
# 20    2019   390
# 21    2020   399
# 22    2021   406
# 23    2022   414
# 24    2023   423

# %%
with open('output/league_ids.json') as f:
    league_ids = json.load(f)

# %%
league_ids
# Out:
# {'2015': 853925,
#  '2016': 810238,
#  '2017': 192551,
#  '2018': 799346,
#  '2019': 820083,
#  '2020': 394682,
#  '2021': 364325,
#  '2022': 564704,
#  '2023': 333146}

# %%
# Uncomment to regenerate standings per modern era year if needed
write_league_standings(game_keys_df, league_ids)
# Out:
# Attempting to write year 2015
# Attempting to write year 2016
# Attempting to write year 2017
# Attempting to write year 2018
# Attempting to write year 2019
# Attempting to write year 2020
# Attempting to write year 2021
# Attempting to write year 2022
# Attempting to write year 2023

# %% [markdown]
# ### Generate fresh standings dataframe

# %%
standings_filenames = [filename.replace('.json','') for filename in os.listdir('./output/standings_by_season/')]

# %%
all_team_stats = []
for file in standings_filenames:
    working_file = data.load(f'standings_by_season/{file}')
    for i in working_file['teams']:
        team_info = i['team'].serialized()
        team_info['season'] = file.replace('standings_year_','')
        all_team_stats.append(team_info)

# %%
standings_to_date_df = pd.json_normalize(all_team_stats)

# %%
standings_to_date_df.to_csv('output/standings_to_date.csv', index=False)

# %%
df = standings_to_date_df.copy()

# %%
mask1 = df['season'] == '2022'

# %%
df22 = df[mask1] 
df22
# Out:
#      clinched_playoffs  division_id draft_grade  draft_position  \
# 0                  1.0          2.0          C+            14.0
# 1                  1.0          1.0           C             7.0
# 2                  1.0          1.0           B            12.0
# 3                  1.0          2.0          C+             9.0
# 4                  1.0          2.0          B-             6.0
# ..                 ...          ...         ...             ...
# 121                NaN          NaN          D-             NaN
# 122                NaN          NaN           C             NaN
# 123                NaN          NaN          A+             NaN
# 124                NaN          NaN          B-             NaN
# 125                NaN          NaN           D             NaN
#
#                                        draft_recap_url  faab_balance  \
# 0    https://football.fantasysports.yahoo.com/2015/...            12
# 1    https://football.fantasysports.yahoo.com/2015/...             0
# 2    https://football.fantasysports.yahoo.com/2015/...             0
# 3    https://football.fantasysports.yahoo.com/2015/...             6
# 4    https://football.fantasysports.yahoo.com/2015/...            60
# ..                                                 ...           ...
# 121  https://football.fantasysports.yahoo.com/f1/33...             5
# 122  https://football.fantasysports.yahoo.com/f1/33...           100
# 123  https://football.fantasysports.yahoo.com/f1/33...           100
# 124  https://football.fantasysports.yahoo.com/f1/33...            21
# 125  https://football.fantasysports.yahoo.com/f1/33...            50
#
#      has_draft_grade league_scoring_type                     name  \
# 0                  1                head         b'Starr is Born'
# 1                  1                head         b'Thug Bungalow'
# 2                  1                head  b'The Ice Cold Bruschi'
# 3                  1                head    b'who invited canada'
# 4                  1                head       b'The fishingtons'
# ..               ...                 ...                      ...
# 121                1                head    b'who invited canada'
# 122                1                head    b"Jadeveon's Hit Men"
# 123                1                head              b'Wereback'
# 124                1                head       b'The fishingtons'
# 125                1                head     b'Saquon These Nuts'
#
#      number_of_moves  ...  team_standings.outcome_totals.percentage  \
# 0                 24  ...                                     0.692
# 1                 28  ...                                     0.615
# 2                 30  ...                                     0.769
# 3                 46  ...                                     0.769
# 4                 23  ...                                     0.615
# ..               ...  ...                                       ...
# 121               21  ...                                     0.429
# 122                5  ...                                     0.429
# 123                6  ...                                     0.357
# 124                9  ...                                     0.286
# 125               10  ...                                     0.214
#
#      team_standings.outcome_totals.ties team_standings.outcome_totals.wins  \
# 0                                     0                                  9
# 1                                     0                                  8
# 2                                     0                                 10
# 3                                     0                                 10
# 4                                     0                                  8
# ..                                  ...                                ...
# 121                                   0                                  6
# 122                                   0                                  6
# 123                                   0                                  5
# 124                                   0                                  4
# 125                                   0                                  3
#
#     team_standings.playoff_seed  team_standings.points_against  \
# 0                           3.0                        1160.91
# 1                           4.0                        1273.94
# 2                           1.0                        1225.08
# 3                           2.0                        1234.93
# 4                           5.0                        1103.02
# ..                          ...                            ...
# 121                        10.0                        1594.64
# 122                        11.0                        1636.64
# 123                        12.0                        1442.22
# 124                         NaN                        1588.12
# 125                         NaN                        1425.98
#
#     team_standings.points_for team_standings.rank team_standings.streak.type  \
# 0                     1302.03                   1                        win
# 1                     1355.37                   2                        win
# 2                     1457.66                   3                        win
# 3                     1425.64                   4                        win
# 4                     1302.04                   5                       loss
# ..                        ...                 ...                        ...
# 121                   1544.62                  10                        win
# 122                   1530.28                  11                       loss
# 123                   1433.82                  12                       loss
# 124                   1422.80                  13                        win
# 125                   1232.10                  14                       loss
#
#      team_standings.streak.value  is_owned_by_current_login
# 0                              5                        NaN
# 1                              2                        1.0
# 2                              1                        NaN
# 3                              2                        NaN
# 4                              1                        NaN
# ..                           ...                        ...
# 121                            1                        NaN
# 122                            2                        NaN
# 123                            1                        NaN
# 124                            1                        NaN
# 125                            2                        NaN
#
# [126 rows x 38 columns]
